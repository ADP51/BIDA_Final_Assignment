# %%
import pandas as pd
from matplotlib import pyplot as plt

df_yearly = pd.read_csv("./data_v2/yearly/2019.csv")
#combine rushing attempts and passing attempts
df_yearly['Touches'] = df_yearly['Rec'] + df_yearly['RushingAtt']
df_yearly.head()
# Out:
#    Unnamed: 0               Player   Tm Pos   Age     G    GS    Cmp    Att  \
# 0           0  Christian McCaffrey  CAR  RB  23.0  16.0  16.0    0.0    2.0
# 1           1        Lamar Jackson  BAL  QB  22.0  15.0  15.0  265.0  401.0
# 2           2        Derrick Henry  TEN  RB  25.0  15.0  15.0    0.0    0.0
# 3           3          Aaron Jones  GNB  RB  25.0  16.0  16.0    0.0    0.0
# 4           4      Ezekiel Elliott  DAL  RB  24.0  16.0  16.0    0.0    0.0
#
#       Yds  ...  PassingYds  PassingTD  PassingAtt  RushingYds  RushingTD  \
# 0     0.0  ...         0.0        0.0         2.0      1387.0       15.0
# 1  3127.0  ...      3127.0       36.0       401.0      1206.0        7.0
# 2     0.0  ...         0.0        0.0         0.0      1540.0       16.0
# 3     0.0  ...         0.0        0.0         0.0      1084.0       16.0
# 4     0.0  ...         0.0        0.0         0.0      1357.0       12.0
#
#    RushingAtt  ReceivingYds  ReceivingTD  FantasyPoints  Touches
# ...

# %%
# plot to see the correlation between the number of times a plyaer touches the ball to the amount of FP
plt.style.use('ggplot')
df_yearly.plot(x='Touches', y='FantasyPoints', kind='scatter')

# %%
# we know there is a strong correlation between touches and points
# lets see which players were the most efficient with their touches
# create new skill position df
df_skillpos = df_yearly[(df_yearly.Pos == 'RB') | (df_yearly.Pos == 'WR') | (df_yearly.Pos == 'TE')] 
df_skillpos.head()
# Out:
#    Unnamed: 0               Player   Tm Pos   Age     G    GS  Cmp  Att  Yds  \
# 0           0  Christian McCaffrey  CAR  RB  23.0  16.0  16.0  0.0  2.0  0.0
# 2           2        Derrick Henry  TEN  RB  25.0  15.0  15.0  0.0  0.0  0.0
# 3           3          Aaron Jones  GNB  RB  25.0  16.0  16.0  0.0  0.0  0.0
# 4           4      Ezekiel Elliott  DAL  RB  24.0  16.0  16.0  0.0  0.0  0.0
# 5           5          Dalvin Cook  MIN  RB  24.0  14.0  14.0  0.0  0.0  0.0
#
#    ...  PassingTD  PassingAtt  RushingYds  RushingTD  RushingAtt  \
# 0  ...        0.0         2.0      1387.0       15.0       287.0
# 2  ...        0.0         0.0      1540.0       16.0       303.0
# 3  ...        0.0         0.0      1084.0       16.0       236.0
# 4  ...        0.0         0.0      1357.0       12.0       301.0
# 5  ...        0.0         0.0      1135.0       13.0       250.0
#
#    ReceivingYds  ReceivingTD  FantasyPoints  Touches       ppt
# ...

# %%
df_skillpos['ppt'] = df_skillpos['FantasyPoints'] / df_skillpos['Touches']
df_skillpos.sort_values(by='ppt', ascending=False)
# Out:
# /Users/andrewpalmer/opt/anaconda3/envs/jupyter/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      Unnamed: 0             Player   Tm Pos   Age     G   GS  Cmp  Att  Yds  \
# 406         406     Ventell Bryant  DAL  WR  23.0  12.0  0.0  0.0  0.0  0.0
# 368         368       Rico Gafford  OAK  WR  23.0   4.0  1.0  0.0  0.0  0.0
# 312         312  Olamide Zaccheaus  ATL  WR  22.0  10.0  0.0  0.0  0.0  0.0
# 405         405       Nick Bellore  SEA  RB  30.0  14.0  1.0  0.0  0.0  0.0
# 270         270        Marvin Hall  DET  WR  26.0   9.0  0.0  0.0  0.0  0.0
# ..          ...                ...  ...  ..   ...   ...  ...  ...  ...  ...
# ...

# %%
# let's remove any player without at least 50 touches
df_skillpos.drop(df_skillpos[df_skillpos.Touches < 50].index, inplace=True)
df_skillpos.sort_values(by='ppt', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-4c138ac0e2cf> in <module>
#       1 # let's remove any player without at least 50 touches
# ----> 2 df_skillpos.drop(df_skillpos[df_skillpos.Touches < 50], inplace=True)
#       3 df_skillpos.sort_values(by='ppt', ascending=False)
#
# ~/opt/anaconda3/envs/jupyter/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/opt/anaconda3/envs/jupyter/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
df_rbyearly.sort_values(by='Touches', ascending=True)
# Out:
#      Unnamed: 0               Player   Tm Pos   Age     G    GS  Cmp  Att  \
# 583         583        Alfred Morris  ARI  RB  31.0   1.0   0.0  0.0  0.0
# 522         522          Ricky Ortiz  NOR  RB  25.0   1.0   0.0  0.0  0.0
# 513         513        Jakob Johnson  NWE  RB  25.0   4.0   3.0  0.0  0.0
# 586         586        Roosevelt Nix  PIT  RB  27.0   3.0   0.0  0.0  0.0
# 550         550        James Develin  NWE  RB  31.0   2.0   2.0  0.0  0.0
# ..          ...                  ...  ...  ..   ...   ...   ...  ...  ...
# 2             2        Derrick Henry  TEN  RB  25.0  15.0  15.0  0.0  0.0
# 8             8           Nick Chubb  CLE  RB  24.0  16.0  16.0  0.0  0.0
# 28           28    Leonard Fournette  JAX  RB  24.0  15.0  15.0  0.0  0.0
# 4             4      Ezekiel Elliott  DAL  RB  24.0  16.0  16.0  0.0  0.0
# 0             0  Christian McCaffrey  CAR  RB  23.0  16.0  16.0  0.0  2.0
#
#      Yds  ...  PassingTD  PassingAtt  RushingYds  RushingTD  RushingAtt  \
# ...

# %%
#split into position groups
df_rbyearly = df_yearly[df_yearly.Pos == 'RB']
df_wryearly = df_yearly[df_yearly.Pos == 'WR']
df_teyearly = df_yearly[df_yearly.Pos == 'TE']
df_qbyearly = df_yearly[df_yearly.Pos == 'QB']

df_rbyearly.head()
# Out:
#    Unnamed: 0               Player   Tm Pos   Age     G    GS  Cmp  Att  Yds  \
# 0           0  Christian McCaffrey  CAR  RB  23.0  16.0  16.0  0.0  2.0  0.0
# 2           2        Derrick Henry  TEN  RB  25.0  15.0  15.0  0.0  0.0  0.0
# 3           3          Aaron Jones  GNB  RB  25.0  16.0  16.0  0.0  0.0  0.0
# 4           4      Ezekiel Elliott  DAL  RB  24.0  16.0  16.0  0.0  0.0  0.0
# 5           5          Dalvin Cook  MIN  RB  24.0  14.0  14.0  0.0  0.0  0.0
#
#    ...  PassingTD  PassingAtt  RushingYds  RushingTD  RushingAtt  \
# 0  ...        0.0         2.0      1387.0       15.0       287.0
# 2  ...        0.0         0.0      1540.0       16.0       303.0
# 3  ...        0.0         0.0      1084.0       16.0       236.0
# 4  ...        0.0         0.0      1357.0       12.0       301.0
# 5  ...        0.0         0.0      1135.0       13.0       250.0
#
#    ReceivingYds  ReceivingTD  FantasyPoints  Touches       ppt
# ...
